# %%
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')

import logging
from gensim.models import word2vec

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
import gensim
# Need the interactive Tools for Matplotlib
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
model = gensim.models.KeyedVectors.load_word2vec_format('entire_corpora.model.bin', binary=True)
# Out:
# 2018-03-28 02:46:20,591 : INFO : loading projection weights from entire_corpora.model.bin
# 2018-03-28 02:46:34,587 : INFO : loaded (108813, 200) matrix from entire_corpora.model.bin

# %%
def most_similar(model, a, b, c, topn=10, topn2=10):
    nearest = model.wv.most_similar(positive=[a, b], negative=[c], topn=topn)
    output = []
    for d, score in nearest:
        cumul_score = score

        other_nearest = model.wv.most_similar(positive=[a, b], negative=[d], topn=topn2)
        for e, other_score in other_nearest:
            if c == e:
                cumul_score = cumul_score + other_score
                break

        other_nearest = model.wv.most_similar(
            positive=[c, d], negative=[a], topn=topn2)
        for e, other_score in other_nearest:
            if b == e:
                cumul_score = cumul_score + other_score
                break

        other_nearest = model.wv.most_similar(
            positive=[c, d], negative=[b], topn=topn2)
        for e, other_score in other_nearest:
            if a == e:
                cumul_score = cumul_score + other_score
                break

        output.append((d, cumul_score))

    return output

# %%
most_similar(model,'babae','tito','lalaki')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bea24dfdc5e0> in <module>()
# ----> 1 most_similar(model,'babae','tito','lalaki')
#
# NameError: name 'most_similar' is not defined

# %%
model.wv.most_similar(positive=['prinsipe', 'dalaga'], negative=['binata'])
# Out:
# [('prinsesa', 0.6678964495658875),
#  ('diwata', 0.6029185652732849),
#  ('dalagita', 0.6027273535728455),
#  ('oso', 0.5654577016830444),
#  ('Birhen', 0.5585415363311768),
#  ('binatilyo', 0.5436294078826904),
#  ('tupa', 0.5353958010673523),
#  ('tango', 0.5343475937843323),
#  ('Apo', 0.5315272212028503),
#  ('Kabalyero', 0.5307762622833252)]

# %%
model.wv.accuracy('output.gender.csv')
# Out:
# 2018-03-28 03:02:50,399 : INFO : gender: 57.1% (156/273)
# 2018-03-28 03:02:50,401 : INFO : total: 57.1% (156/273)
# [{'correct': [('PRINSESA', 'DALAGA', 'PRINSIPE', 'BINATA'),
#    ('HIPAG', 'DALAGA', 'BAYAW', 'BINATA'),
#    ('NINANG', 'REYNA', 'NINONG', 'HARI'),
#    ('NANAY', 'LOLA', 'TATAY', 'LOLO'),
#    ('INA', 'LOLA', 'AMA', 'LOLO'),
#    ('BABAE', 'DALAGA', 'LALAKI', 'BINATA'),
#    ('LOLA', 'BABAE', 'LOLO', 'LALAKI'),
#    ('BABAE', 'PRINSESA', 'LALAKI', 'PRINSIPE'),
#    ('PRINSESA', 'DALAGA', 'PRINSIPE', 'BINATA'),
#    ('BABAE', 'PRINSESA', 'LALAKI', 'PRINSIPE'),
#    ('NANAY', 'BABAE', 'TATAY', 'LALAKI'),
#    ('NANAY', 'KUYA', 'TATAY', 'ATE'),
#    ('NANAY', 'DALAGA', 'TATAY', 'BINATA'),
#    ('INA', 'REYNA', 'AMA', 'HARI'),
#    ('KUYA', 'BABAE', 'ATE', 'LALAKI'),
#    ('TIYA', 'BABAE', 'TIYO', 'LALAKI'),
#    ('LOLA', 'DALAGA', 'LOLO', 'BINATA'),
#    ('INA', 'TIYA', 'AMA', 'TIYO'),
#    ('KUYA', 'DALAGA', 'ATE', 'BINATA'),
#    ('HIPAG', 'MAMA', 'BAYAW', 'PAPA'),
#    ('BABAE', 'DALAGA', 'LALAKI', 'BINATA'),
#    ('PRINSESA', 'REYNA', 'PRINSIPE', 'HARI'),
#    ('REYNA', 'DALAGA', 'HARI', 'BINATA'),
#    ('TITA', 'BABAE', 'TITO', 'LALAKI'),
#    ('INA', 'REYNA', 'AMA', 'HARI'),
#    ('INA', 'BABAE', 'AMA', 'LALAKI'),
#    ('LOLA', 'TIYA', 'LOLO', 'TIYO'),
#    ('INA', 'MAMA', 'AMA', 'PAPA'),
#    ('ERMAT', 'DALAGA', 'ERPAT', 'BINATA'),
#    ('INA', 'MAMA', 'AMA', 'PAPA'),
#    ('TIYA', 'BABAE', 'TIYO', 'LALAKI'),
#    ('REYNA', 'DALAGA', 'HARI', 'BINATA'),
#    ('NINANG', 'REYNA', 'NINONG', 'HARI'),
#    ('INA', 'NANAY', 'AMA', 'TATAY'),
#    ('INA', 'DALAGA', 'AMA', 'BINATA'),
#    ('INA', 'MAMA', 'AMA', 'PAPA'),
#    ('LOLA', 'TIYA', 'LOLO', 'TIYO'),
#    ('KUYA', 'MAMA', 'ATE', 'PAPA'),
#    ('PRINSESA', 'REYNA', 'PRINSIPE', 'HARI'),
#    ('DALAGA', 'MAMA', 'BINATA', 'PAPA'),
#    ('LOLA', 'NINANG', 'LOLO', 'NINONG'),
#    ('INA', 'TIYA', 'AMA', 'TIYO'),
#    ('TIYA', 'HIPAG', 'TIYO', 'BAYAW'),
#    ('PRINSESA', 'REYNA', 'PRINSIPE', 'HARI'),
#    ('HIPAG', 'DALAGA', 'BAYAW', 'BINATA'),
#    ('NINANG', 'MAMA', 'NINONG', 'PAPA'),
#    ('NANAY', 'NINANG', 'TATAY', 'NINONG'),
#    ('LOLA', 'BABAE', 'LOLO', 'LALAKI'),
#    ('REYNA', 'DALAGA', 'HARI', 'BINATA'),
#    ('TIYA', 'BABAE', 'TIYO', 'LALAKI'),
#    ('ERMAT', 'DALAGA', 'ERPAT', 'BINATA'),
#    ('TITA', 'DALAGA', 'TITO', 'BINATA'),
#    ('PRINSESA', 'DALAGA', 'PRINSIPE', 'BINATA'),
#    ('DALAGA', 'MAMA', 'BINATA', 'PAPA'),
#    ('TITA', 'DALAGA', 'TITO', 'BINATA'),
#    ('NANAY', 'DALAGA', 'TATAY', 'BINATA'),
#    ('NANAY', 'NINANG', 'TATAY', 'NINONG'),
#    ('NANAY', 'ERMAT', 'TATAY', 'ERPAT'),
#    ('NANAY', 'DALAGA', 'TATAY', 'BINATA'),
#    ('HIPAG', 'BABAE', 'BAYAW', 'LALAKI'),
#    ('BABAE', 'REYNA', 'LALAKI', 'HARI'),
#    ('DALAGA', 'MAMA', 'BINATA', 'PAPA'),
#    ('LOLA', 'NINANG', 'LOLO', 'NINONG'),
#    ('NINANG', 'MAMA', 'NINONG', 'PAPA'),
#    ('NANAY', 'ERMAT', 'TATAY', 'ERPAT'),
#    ('ERMAT', 'BABAE', 'ERPAT', 'LALAKI'),
#    ('KUYA', 'LOLA', 'ATE', 'LOLO'),
#    ('NINANG', 'DALAGA', 'NINONG', 'BINATA'),
#    ('KUYA', 'LOLA', 'ATE', 'LOLO'),
#    ('NINANG', 'BABAE', 'NINONG', 'LALAKI'),
#    ('TIYA', 'HIPAG', 'TIYO', 'BAYAW'),
#    ('INA', 'NANAY', 'AMA', 'TATAY'),
#    ('TIYA', 'DALAGA', 'TIYO', 'BINATA'),
#    ('KUYA', 'DALAGA', 'ATE', 'BINATA'),
#    ('NANAY', 'LOLA', 'TATAY', 'LOLO'),
#    ('NANAY', 'ERMAT', 'TATAY', 'ERPAT'),
#    ('KUYA', 'TIYA', 'ATE', 'TIYO'),
#    ('INA', 'KUYA', 'AMA', 'ATE'),
#    ('TIYA', 'NINANG', 'TIYO', 'NINONG'),
#    ('NINANG', 'DALAGA', 'NINONG', 'BINATA'),
#    ('NANAY', 'BABAE', 'TATAY', 'LALAKI'),
#    ('INA', 'BABAE', 'AMA', 'LALAKI'),
#    ('NINANG', 'PRINSESA', 'NINONG', 'PRINSIPE'),
#    ('TIYA', 'NINANG', 'TIYO', 'NINONG'),
#    ('TITA', 'BABAE', 'TITO', 'LALAKI'),
#    ('INA', 'KUYA', 'AMA', 'ATE'),
#    ('INA', 'BABAE', 'AMA', 'LALAKI'),
#    ('LOLA', 'REYNA', 'LOLO', 'HARI'),
#    ('NANAY', 'LOLA', 'TATAY', 'LOLO'),
#    ('NINANG', 'MAMA', 'NINONG', 'PAPA'),
#    ('NINANG', 'DALAGA', 'NINONG', 'BINATA'),
#    ('HIPAG', 'BABAE', 'BAYAW', 'LALAKI'),
#    ('LOLA', 'BABAE', 'LOLO', 'LALAKI'),
#    ('HIPAG', 'MAMA', 'BAYAW', 'PAPA'),
#    ('BABAE', 'REYNA', 'LALAKI', 'HARI'),
#    ('ERMAT', 'BABAE', 'ERPAT', 'LALAKI'),
#    ('LOLA', 'DALAGA', 'LOLO', 'BINATA'),
#    ('ERMAT', 'BABAE', 'ERPAT', 'LALAKI'),
#    ('TITA', 'BABAE', 'TITO', 'LALAKI'),
#    ('BABAE', 'REYNA', 'LALAKI', 'HARI'),
#    ('NANAY', 'MAMA', 'TATAY', 'PAPA'),
#    ('NANAY', 'MAMA', 'TATAY', 'PAPA'),
#    ('TIYA', 'DALAGA', 'TIYO', 'BINATA'),
#    ('NANAY', 'REYNA', 'TATAY', 'HARI'),
#    ('BABAE', 'PRINSESA', 'LALAKI', 'PRINSIPE'),
#    ('KUYA', 'LOLA', 'ATE', 'LOLO'),
#    ('NINANG', 'PRINSESA', 'NINONG', 'PRINSIPE'),
#    ('LOLA', 'ERMAT', 'LOLO', 'ERPAT'),
#    ('INA', 'LOLA', 'AMA', 'LOLO'),
#    ('INA', 'DALAGA', 'AMA', 'BINATA'),
#    ('INA', 'NINANG', 'AMA', 'NINONG'),
#    ('KUYA', 'DALAGA', 'ATE', 'BINATA'),
#    ('HIPAG', 'BABAE', 'BAYAW', 'LALAKI'),
#    ('BABAE', 'DALAGA', 'LALAKI', 'BINATA'),
#    ('INA', 'NANAY', 'AMA', 'TATAY'),
#    ('KUYA', 'TIYA', 'ATE', 'TIYO'),
#    ('KUYA', 'BABAE', 'ATE', 'LALAKI'),
#    ('NINANG', 'REYNA', 'NINONG', 'HARI'),
#    ('NANAY', 'BABAE', 'TATAY', 'LALAKI'),
#    ('TITA', 'DALAGA', 'TITO', 'BINATA'),
#    ('TIYA', 'DALAGA', 'TIYO', 'BINATA'),
#    ('NANAY', 'KUYA', 'TATAY', 'ATE'),
#    ('LOLA', 'REYNA', 'LOLO', 'HARI'),
#    ('HIPAG', 'DALAGA', 'BAYAW', 'BINATA'),
#    ('INA', 'REYNA', 'AMA', 'HARI'),
#    ('KUYA', 'BABAE', 'ATE', 'LALAKI'),
#    ('NANAY', 'REYNA', 'TATAY', 'HARI'),
#    ('INA', 'DALAGA', 'AMA', 'BINATA'),
#    ('NANAY', 'KUYA', 'TATAY', 'ATE'),
#    ('LOLA', 'TIYA', 'LOLO', 'TIYO'),
#    ('NINANG', 'PRINSESA', 'NINONG', 'PRINSIPE'),
#    ('KUYA', 'TIYA', 'ATE', 'TIYO'),
#    ('INA', 'KUYA', 'AMA', 'ATE'),
#    ('ERMAT', 'DALAGA', 'ERPAT', 'BINATA'),
#    ('TIYA', 'NINANG', 'TIYO', 'NINONG'),
#    ('INA', 'TIYA', 'AMA', 'TIYO'),
#    ('NINANG', 'BABAE', 'NINONG', 'LALAKI'),
#    ('LOLA', 'NINANG', 'LOLO', 'NINONG'),
#    ('NINANG', 'BABAE', 'NINONG', 'LALAKI'),
#    ('INA', 'LOLA', 'AMA', 'LOLO'),
#    ('LOLA', 'ERMAT', 'LOLO', 'ERPAT'),
#    ('LOLA', 'REYNA', 'LOLO', 'HARI'),
#    ('NANAY', 'MAMA', 'TATAY', 'PAPA'),
#    ('HIPAG', 'MAMA', 'BAYAW', 'PAPA'),
#    ('KUYA', 'MAMA', 'ATE', 'PAPA'),
#    ('LOLA', 'ERMAT', 'LOLO', 'ERPAT'),
#    ('LOLA', 'MAMA', 'LOLO', 'PAPA'),
#    ('KUYA', 'MAMA', 'ATE', 'PAPA'),
#    ('INA', 'NINANG', 'AMA', 'NINONG'),
#    ('NANAY', 'NINANG', 'TATAY', 'NINONG'),
#    ('INA', 'NINANG', 'AMA', 'NINONG'),
#    ('LOLA', 'MAMA', 'LOLO', 'PAPA'),
#    ('TIYA', 'HIPAG', 'TIYO', 'BAYAW'),
#    ('LOLA', 'DALAGA', 'LOLO', 'BINATA'),
#    ('LOLA', 'MAMA', 'LOLO', 'PAPA'),
#    ('NANAY', 'REYNA', 'TATAY', 'HARI')],
#   'incorrect': [('KUYA', 'TITA', 'ATE', 'TITO'),
#    ('HIPAG', 'TITA', 'BAYAW', 'TITO'),
#    ('TIYA', 'TITA', 'TIYO', 'TITO'),
#    ('ERMAT', 'PRINSESA', 'ERPAT', 'PRINSIPE'),
#    ('REYNA', 'MAMA', 'HARI', 'PAPA'),
#    ('HIPAG', 'REYNA', 'BAYAW', 'HARI'),
#    ('KUYA', 'TITA', 'ATE', 'TITO'),
#    ('KUYA', 'NINANG', 'ATE', 'NINONG'),
#    ('TITA', 'PRINSESA', 'TITO', 'PRINSIPE'),
#    ('REYNA', 'MAMA', 'HARI', 'PAPA'),
#    ('TITA', 'MAMA', 'TITO', 'PAPA'),
#    ('KUYA', 'PRINSESA', 'ATE', 'PRINSIPE'),
#    ('ERMAT', 'REYNA', 'ERPAT', 'HARI'),
#    ('KUYA', 'TITA', 'ATE', 'TITO'),
#    ('KUYA', 'ERMAT', 'ATE', 'ERPAT'),
#    ('REYNA', 'MAMA', 'HARI', 'PAPA'),
#    ('ERMAT', 'MAMA', 'ERPAT', 'PAPA'),
#    ('PRINSESA', 'MAMA', 'PRINSIPE', 'PAPA'),
#    ('NANAY', 'TIYA', 'TATAY', 'TIYO'),
#    ('NANAY', 'PRINSESA', 'TATAY', 'PRINSIPE'),
#    ('TIYA', 'REYNA', 'TIYO', 'HARI'),
#    ('HIPAG', 'TITA', 'BAYAW', 'TITO'),
#    ('KUYA', 'NINANG', 'ATE', 'NINONG'),
#    ('KUYA', 'REYNA', 'ATE', 'HARI'),
#    ('TIYA', 'REYNA', 'TIYO', 'HARI'),
#    ('HIPAG', 'PRINSESA', 'BAYAW', 'PRINSIPE'),
#    ('TIYA', 'ERMAT', 'TIYO', 'ERPAT'),
#    ('LOLA', 'HIPAG', 'LOLO', 'BAYAW'),
#    ('PRINSESA', 'MAMA', 'PRINSIPE', 'PAPA'),
#    ('TITA', 'REYNA', 'TITO', 'HARI'),
#    ('TIYA', 'ERMAT', 'TIYO', 'ERPAT'),
#    ('BABAE', 'MAMA', 'LALAKI', 'PAPA'),
#    ('NINANG', 'ERMAT', 'NINONG', 'ERPAT'),
#    ('TITA', 'PRINSESA', 'TITO', 'PRINSIPE'),
#    ('NINANG', 'ERMAT', 'NINONG', 'ERPAT'),
#    ('NANAY', 'TITA', 'TATAY', 'TITO'),
#    ('NANAY', 'PRINSESA', 'TATAY', 'PRINSIPE'),
#    ('INA', 'PRINSESA', 'AMA', 'PRINSIPE'),
#    ('TITA', 'ERMAT', 'TITO', 'ERPAT'),
#    ('INA', 'ERMAT', 'AMA', 'ERPAT'),
#    ('ERMAT', 'REYNA', 'ERPAT', 'HARI'),
#    ('KUYA', 'HIPAG', 'ATE', 'BAYAW'),
#    ('INA', 'HIPAG', 'AMA', 'BAYAW'),
#    ('TITA', 'REYNA', 'TITO', 'HARI'),
#    ('INA', 'TITA', 'AMA', 'TITO'),
#    ('INA', 'PRINSESA', 'AMA', 'PRINSIPE'),
#    ('TITA', 'REYNA', 'TITO', 'HARI'),
#    ('TITA', 'ERMAT', 'TITO', 'ERPAT'),
#    ('LOLA', 'TITA', 'LOLO', 'TITO'),
#    ('LOLA', 'TITA', 'LOLO', 'TITO'),
#    ('HIPAG', 'REYNA', 'BAYAW', 'HARI'),
#    ('HIPAG', 'TITA', 'BAYAW', 'TITO'),
#    ('TITA', 'ERMAT', 'TITO', 'ERPAT'),
#    ('NANAY', 'HIPAG', 'TATAY', 'BAYAW'),
#    ('NANAY', 'HIPAG', 'TATAY', 'BAYAW'),
#    ('KUYA', 'PRINSESA', 'ATE', 'PRINSIPE'),
#    ('ERMAT', 'MAMA', 'ERPAT', 'PAPA'),
#    ('TIYA', 'MAMA', 'TIYO', 'PAPA'),
#    ('TITA', 'MAMA', 'TITO', 'PAPA'),
#    ('LOLA', 'PRINSESA', 'LOLO', 'PRINSIPE'),
#    ('TIYA', 'MAMA', 'TIYO', 'PAPA'),
#    ('NINANG', 'HIPAG', 'NINONG', 'BAYAW'),
#    ('NANAY', 'TIYA', 'TATAY', 'TIYO'),
#    ('TIYA', 'REYNA', 'TIYO', 'HARI'),
#    ('ERMAT', 'REYNA', 'ERPAT', 'HARI'),
#    ('BABAE', 'MAMA', 'LALAKI', 'PAPA'),
#    ('ERMAT', 'MAMA', 'ERPAT', 'PAPA'),
#    ('HIPAG', 'ERMAT', 'BAYAW', 'ERPAT'),
#    ('TIYA', 'PRINSESA', 'TIYO', 'PRINSIPE'),
#    ('PRINSESA', 'MAMA', 'PRINSIPE', 'PAPA'),
#    ('HIPAG', 'ERMAT', 'BAYAW', 'ERPAT'),
#    ('KUYA', 'PRINSESA', 'ATE', 'PRINSIPE'),
#    ('HIPAG', 'PRINSESA', 'BAYAW', 'PRINSIPE'),
#    ('BABAE', 'MAMA', 'LALAKI', 'PAPA'),
#    ('NINANG', 'HIPAG', 'NINONG', 'BAYAW'),
#    ('HIPAG', 'PRINSESA', 'BAYAW', 'PRINSIPE'),
#    ('TITA', 'MAMA', 'TITO', 'PAPA'),
#    ('NANAY', 'TITA', 'TATAY', 'TITO'),
#    ('INA', 'TITA', 'AMA', 'TITO'),
#    ('ERMAT', 'PRINSESA', 'ERPAT', 'PRINSIPE'),
#    ('TITA', 'PRINSESA', 'TITO', 'PRINSIPE'),
#    ('LOLA', 'PRINSESA', 'LOLO', 'PRINSIPE'),
#    ('NINANG', 'HIPAG', 'NINONG', 'BAYAW'),
#    ('INA', 'ERMAT', 'AMA', 'ERPAT'),
#    ('INA', 'PRINSESA', 'AMA', 'PRINSIPE'),
#    ('NINANG', 'ERMAT', 'NINONG', 'ERPAT'),
#    ('LOLA', 'HIPAG', 'LOLO', 'BAYAW'),
#    ('KUYA', 'REYNA', 'ATE', 'HARI'),
#    ('KUYA', 'HIPAG', 'ATE', 'BAYAW'),
#    ('INA', 'ERMAT', 'AMA', 'ERPAT'),
#    ('NINANG', 'TITA', 'NINONG', 'TITO'),
#    ('TIYA', 'TITA', 'TIYO', 'TITO'),
#    ('ERMAT', 'PRINSESA', 'ERPAT', 'PRINSIPE'),
#    ('NANAY', 'TIYA', 'TATAY', 'TIYO'),
#    ('TIYA', 'PRINSESA', 'TIYO', 'PRINSIPE'),
#    ('LOLA', 'PRINSESA', 'LOLO', 'PRINSIPE'),
#    ('TIYA', 'ERMAT', 'TIYO', 'ERPAT'),
#    ('KUYA', 'ERMAT', 'ATE', 'ERPAT'),
#    ('INA', 'HIPAG', 'AMA', 'BAYAW'),
#    ('NANAY', 'PRINSESA', 'TATAY', 'PRINSIPE'),
#    ('HIPAG', 'ERMAT', 'BAYAW', 'ERPAT'),
#    ('LOLA', 'TITA', 'LOLO', 'TITO'),
#    ('KUYA', 'HIPAG', 'ATE', 'BAYAW'),
#    ('HIPAG', 'REYNA', 'BAYAW', 'HARI'),
#    ('INA', 'HIPAG', 'AMA', 'BAYAW'),
#    ('TIYA', 'MAMA', 'TIYO', 'PAPA'),
#    ('KUYA', 'ERMAT', 'ATE', 'ERPAT'),
#    ('TIYA', 'PRINSESA', 'TIYO', 'PRINSIPE'),
#    ('KUYA', 'REYNA', 'ATE', 'HARI'),
#    ('TIYA', 'TITA', 'TIYO', 'TITO'),
#    ('INA', 'TITA', 'AMA', 'TITO'),
#    ('LOLA', 'HIPAG', 'LOLO', 'BAYAW'),
#    ('KUYA', 'NINANG', 'ATE', 'NINONG'),
#    ('NANAY', 'HIPAG', 'TATAY', 'BAYAW'),
#    ('NINANG', 'TITA', 'NINONG', 'TITO'),
#    ('NINANG', 'TITA', 'NINONG', 'TITO'),
#    ('NANAY', 'TITA', 'TATAY', 'TITO')],
#   'section': 'gender'},
#  {'correct': [('PRINSESA', 'DALAGA', 'PRINSIPE', 'BINATA'),
#    ('HIPAG', 'DALAGA', 'BAYAW', 'BINATA'),
#    ('NINANG', 'REYNA', 'NINONG', 'HARI'),
#    ('NANAY', 'LOLA', 'TATAY', 'LOLO'),
#    ('INA', 'LOLA', 'AMA', 'LOLO'),
#    ('BABAE', 'DALAGA', 'LALAKI', 'BINATA'),
#    ('LOLA', 'BABAE', 'LOLO', 'LALAKI'),
#    ('BABAE', 'PRINSESA', 'LALAKI', 'PRINSIPE'),
#    ('PRINSESA', 'DALAGA', 'PRINSIPE', 'BINATA'),
#    ('BABAE', 'PRINSESA', 'LALAKI', 'PRINSIPE'),
#    ('NANAY', 'BABAE', 'TATAY', 'LALAKI'),
#    ('NANAY', 'KUYA', 'TATAY', 'ATE'),
#    ('NANAY', 'DALAGA', 'TATAY', 'BINATA'),
#    ('INA', 'REYNA', 'AMA', 'HARI'),
#    ('KUYA', 'BABAE', 'ATE', 'LALAKI'),
#    ('TIYA', 'BABAE', 'TIYO', 'LALAKI'),
#    ('LOLA', 'DALAGA', 'LOLO', 'BINATA'),
#    ('INA', 'TIYA', 'AMA', 'TIYO'),
#    ('KUYA', 'DALAGA', 'ATE', 'BINATA'),
#    ('HIPAG', 'MAMA', 'BAYAW', 'PAPA'),
#    ('BABAE', 'DALAGA', 'LALAKI', 'BINATA'),
#    ('PRINSESA', 'REYNA', 'PRINSIPE', 'HARI'),
#    ('REYNA', 'DALAGA', 'HARI', 'BINATA'),
#    ('TITA', 'BABAE', 'TITO', 'LALAKI'),
#    ('INA', 'REYNA', 'AMA', 'HARI'),
#    ('INA', 'BABAE', 'AMA', 'LALAKI'),
#    ('LOLA', 'TIYA', 'LOLO', 'TIYO'),
#    ('INA', 'MAMA', 'AMA', 'PAPA'),
#    ('ERMAT', 'DALAGA', 'ERPAT', 'BINATA'),
#    ('INA', 'MAMA', 'AMA', 'PAPA'),
#    ('TIYA', 'BABAE', 'TIYO', 'LALAKI'),
#    ('REYNA', 'DALAGA', 'HARI', 'BINATA'),
#    ('NINANG', 'REYNA', 'NINONG', 'HARI'),
#    ('INA', 'NANAY', 'AMA', 'TATAY'),
#    ('INA', 'DALAGA', 'AMA', 'BINATA'),
#    ('INA', 'MAMA', 'AMA', 'PAPA'),
#    ('LOLA', 'TIYA', 'LOLO', 'TIYO'),
#    ('KUYA', 'MAMA', 'ATE', 'PAPA'),
#    ('PRINSESA', 'REYNA', 'PRINSIPE', 'HARI'),
#    ('DALAGA', 'MAMA', 'BINATA', 'PAPA'),
#    ('LOLA', 'NINANG', 'LOLO', 'NINONG'),
#    ('INA', 'TIYA', 'AMA', 'TIYO'),
#    ('TIYA', 'HIPAG', 'TIYO', 'BAYAW'),
#    ('PRINSESA', 'REYNA', 'PRINSIPE', 'HARI'),
#    ('HIPAG', 'DALAGA', 'BAYAW', 'BINATA'),
#    ('NINANG', 'MAMA', 'NINONG', 'PAPA'),
#    ('NANAY', 'NINANG', 'TATAY', 'NINONG'),
#    ('LOLA', 'BABAE', 'LOLO', 'LALAKI'),
#    ('REYNA', 'DALAGA', 'HARI', 'BINATA'),
#    ('TIYA', 'BABAE', 'TIYO', 'LALAKI'),
#    ('ERMAT', 'DALAGA', 'ERPAT', 'BINATA'),
#    ('TITA', 'DALAGA', 'TITO', 'BINATA'),
#    ('PRINSESA', 'DALAGA', 'PRINSIPE', 'BINATA'),
#    ('DALAGA', 'MAMA', 'BINATA', 'PAPA'),
#    ('TITA', 'DALAGA', 'TITO', 'BINATA'),
#    ('NANAY', 'DALAGA', 'TATAY', 'BINATA'),
#    ('NANAY', 'NINANG', 'TATAY', 'NINONG'),
#    ('NANAY', 'ERMAT', 'TATAY', 'ERPAT'),
#    ('NANAY', 'DALAGA', 'TATAY', 'BINATA'),
#    ('HIPAG', 'BABAE', 'BAYAW', 'LALAKI'),
#    ('BABAE', 'REYNA', 'LALAKI', 'HARI'),
#    ('DALAGA', 'MAMA', 'BINATA', 'PAPA'),
#    ('LOLA', 'NINANG', 'LOLO', 'NINONG'),
#    ('NINANG', 'MAMA', 'NINONG', 'PAPA'),
#    ('NANAY', 'ERMAT', 'TATAY', 'ERPAT'),
#    ('ERMAT', 'BABAE', 'ERPAT', 'LALAKI'),
#    ('KUYA', 'LOLA', 'ATE', 'LOLO'),
#    ('NINANG', 'DALAGA', 'NINONG', 'BINATA'),
#    ('KUYA', 'LOLA', 'ATE', 'LOLO'),
#    ('NINANG', 'BABAE', 'NINONG', 'LALAKI'),
#    ('TIYA', 'HIPAG', 'TIYO', 'BAYAW'),
#    ('INA', 'NANAY', 'AMA', 'TATAY'),
#    ('TIYA', 'DALAGA', 'TIYO', 'BINATA'),
#    ('KUYA', 'DALAGA', 'ATE', 'BINATA'),
#    ('NANAY', 'LOLA', 'TATAY', 'LOLO'),
#    ('NANAY', 'ERMAT', 'TATAY', 'ERPAT'),
#    ('KUYA', 'TIYA', 'ATE', 'TIYO'),
#    ('INA', 'KUYA', 'AMA', 'ATE'),
#    ('TIYA', 'NINANG', 'TIYO', 'NINONG'),
#    ('NINANG', 'DALAGA', 'NINONG', 'BINATA'),
#    ('NANAY', 'BABAE', 'TATAY', 'LALAKI'),
#    ('INA', 'BABAE', 'AMA', 'LALAKI'),
#    ('NINANG', 'PRINSESA', 'NINONG', 'PRINSIPE'),
#    ('TIYA', 'NINANG', 'TIYO', 'NINONG'),
#    ('TITA', 'BABAE', 'TITO', 'LALAKI'),
#    ('INA', 'KUYA', 'AMA', 'ATE'),
#    ('INA', 'BABAE', 'AMA', 'LALAKI'),
#    ('LOLA', 'REYNA', 'LOLO', 'HARI'),
#    ('NANAY', 'LOLA', 'TATAY', 'LOLO'),
#    ('NINANG', 'MAMA', 'NINONG', 'PAPA'),
#    ('NINANG', 'DALAGA', 'NINONG', 'BINATA'),
#    ('HIPAG', 'BABAE', 'BAYAW', 'LALAKI'),
#    ('LOLA', 'BABAE', 'LOLO', 'LALAKI'),
#    ('HIPAG', 'MAMA', 'BAYAW', 'PAPA'),
#    ('BABAE', 'REYNA', 'LALAKI', 'HARI'),
#    ('ERMAT', 'BABAE', 'ERPAT', 'LALAKI'),
#    ('LOLA', 'DALAGA', 'LOLO', 'BINATA'),
#    ('ERMAT', 'BABAE', 'ERPAT', 'LALAKI'),
#    ('TITA', 'BABAE', 'TITO', 'LALAKI'),
#    ('BABAE', 'REYNA', 'LALAKI', 'HARI'),
#    ('NANAY', 'MAMA', 'TATAY', 'PAPA'),
#    ('NANAY', 'MAMA', 'TATAY', 'PAPA'),
#    ('TIYA', 'DALAGA', 'TIYO', 'BINATA'),
#    ('NANAY', 'REYNA', 'TATAY', 'HARI'),
#    ('BABAE', 'PRINSESA', 'LALAKI', 'PRINSIPE'),
#    ('KUYA', 'LOLA', 'ATE', 'LOLO'),
#    ('NINANG', 'PRINSESA', 'NINONG', 'PRINSIPE'),
#    ('LOLA', 'ERMAT', 'LOLO', 'ERPAT'),
#    ('INA', 'LOLA', 'AMA', 'LOLO'),
#    ('INA', 'DALAGA', 'AMA', 'BINATA'),
#    ('INA', 'NINANG', 'AMA', 'NINONG'),
#    ('KUYA', 'DALAGA', 'ATE', 'BINATA'),
#    ('HIPAG', 'BABAE', 'BAYAW', 'LALAKI'),
#    ('BABAE', 'DALAGA', 'LALAKI', 'BINATA'),
#    ('INA', 'NANAY', 'AMA', 'TATAY'),
#    ('KUYA', 'TIYA', 'ATE', 'TIYO'),
#    ('KUYA', 'BABAE', 'ATE', 'LALAKI'),
#    ('NINANG', 'REYNA', 'NINONG', 'HARI'),
#    ('NANAY', 'BABAE', 'TATAY', 'LALAKI'),
#    ('TITA', 'DALAGA', 'TITO', 'BINATA'),
#    ('TIYA', 'DALAGA', 'TIYO', 'BINATA'),
#    ('NANAY', 'KUYA', 'TATAY', 'ATE'),
#    ('LOLA', 'REYNA', 'LOLO', 'HARI'),
#    ('HIPAG', 'DALAGA', 'BAYAW', 'BINATA'),
#    ('INA', 'REYNA', 'AMA', 'HARI'),
#    ('KUYA', 'BABAE', 'ATE', 'LALAKI'),
#    ('NANAY', 'REYNA', 'TATAY', 'HARI'),
#    ('INA', 'DALAGA', 'AMA', 'BINATA'),
#    ('NANAY', 'KUYA', 'TATAY', 'ATE'),
#    ('LOLA', 'TIYA', 'LOLO', 'TIYO'),
#    ('NINANG', 'PRINSESA', 'NINONG', 'PRINSIPE'),
#    ('KUYA', 'TIYA', 'ATE', 'TIYO'),
#    ('INA', 'KUYA', 'AMA', 'ATE'),
#    ('ERMAT', 'DALAGA', 'ERPAT', 'BINATA'),
#    ('TIYA', 'NINANG', 'TIYO', 'NINONG'),
#    ('INA', 'TIYA', 'AMA', 'TIYO'),
#    ('NINANG', 'BABAE', 'NINONG', 'LALAKI'),
#    ('LOLA', 'NINANG', 'LOLO', 'NINONG'),
#    ('NINANG', 'BABAE', 'NINONG', 'LALAKI'),
#    ('INA', 'LOLA', 'AMA', 'LOLO'),
#    ('LOLA', 'ERMAT', 'LOLO', 'ERPAT'),
#    ('LOLA', 'REYNA', 'LOLO', 'HARI'),
#    ('NANAY', 'MAMA', 'TATAY', 'PAPA'),
#    ('HIPAG', 'MAMA', 'BAYAW', 'PAPA'),
#    ('KUYA', 'MAMA', 'ATE', 'PAPA'),
#    ('LOLA', 'ERMAT', 'LOLO', 'ERPAT'),
#    ('LOLA', 'MAMA', 'LOLO', 'PAPA'),
#    ('KUYA', 'MAMA', 'ATE', 'PAPA'),
#    ('INA', 'NINANG', 'AMA', 'NINONG'),
#    ('NANAY', 'NINANG', 'TATAY', 'NINONG'),
#    ('INA', 'NINANG', 'AMA', 'NINONG'),
#    ('LOLA', 'MAMA', 'LOLO', 'PAPA'),
#    ('TIYA', 'HIPAG', 'TIYO', 'BAYAW'),
#    ('LOLA', 'DALAGA', 'LOLO', 'BINATA'),
#    ('LOLA', 'MAMA', 'LOLO', 'PAPA'),
#    ('NANAY', 'REYNA', 'TATAY', 'HARI')],
#   'incorrect': [('KUYA', 'TITA', 'ATE', 'TITO'),
#    ('HIPAG', 'TITA', 'BAYAW', 'TITO'),
#    ('TIYA', 'TITA', 'TIYO', 'TITO'),
#    ('ERMAT', 'PRINSESA', 'ERPAT', 'PRINSIPE'),
#    ('REYNA', 'MAMA', 'HARI', 'PAPA'),
#    ('HIPAG', 'REYNA', 'BAYAW', 'HARI'),
#    ('KUYA', 'TITA', 'ATE', 'TITO'),
#    ('KUYA', 'NINANG', 'ATE', 'NINONG'),
#    ('TITA', 'PRINSESA', 'TITO', 'PRINSIPE'),
#    ('REYNA', 'MAMA', 'HARI', 'PAPA'),
#    ('TITA', 'MAMA', 'TITO', 'PAPA'),
#    ('KUYA', 'PRINSESA', 'ATE', 'PRINSIPE'),
#    ('ERMAT', 'REYNA', 'ERPAT', 'HARI'),
#    ('KUYA', 'TITA', 'ATE', 'TITO'),
#    ('KUYA', 'ERMAT', 'ATE', 'ERPAT'),
#    ('REYNA', 'MAMA', 'HARI', 'PAPA'),
#    ('ERMAT', 'MAMA', 'ERPAT', 'PAPA'),
#    ('PRINSESA', 'MAMA', 'PRINSIPE', 'PAPA'),
#    ('NANAY', 'TIYA', 'TATAY', 'TIYO'),
#    ('NANAY', 'PRINSESA', 'TATAY', 'PRINSIPE'),
#    ('TIYA', 'REYNA', 'TIYO', 'HARI'),
#    ('HIPAG', 'TITA', 'BAYAW', 'TITO'),
#    ('KUYA', 'NINANG', 'ATE', 'NINONG'),
#    ('KUYA', 'REYNA', 'ATE', 'HARI'),
#    ('TIYA', 'REYNA', 'TIYO', 'HARI'),
#    ('HIPAG', 'PRINSESA', 'BAYAW', 'PRINSIPE'),
#    ('TIYA', 'ERMAT', 'TIYO', 'ERPAT'),
#    ('LOLA', 'HIPAG', 'LOLO', 'BAYAW'),
#    ('PRINSESA', 'MAMA', 'PRINSIPE', 'PAPA'),
#    ('TITA', 'REYNA', 'TITO', 'HARI'),
#    ('TIYA', 'ERMAT', 'TIYO', 'ERPAT'),
#    ('BABAE', 'MAMA', 'LALAKI', 'PAPA'),
#    ('NINANG', 'ERMAT', 'NINONG', 'ERPAT'),
#    ('TITA', 'PRINSESA', 'TITO', 'PRINSIPE'),
#    ('NINANG', 'ERMAT', 'NINONG', 'ERPAT'),
#    ('NANAY', 'TITA', 'TATAY', 'TITO'),
#    ('NANAY', 'PRINSESA', 'TATAY', 'PRINSIPE'),
#    ('INA', 'PRINSESA', 'AMA', 'PRINSIPE'),
#    ('TITA', 'ERMAT', 'TITO', 'ERPAT'),
#    ('INA', 'ERMAT', 'AMA', 'ERPAT'),
#    ('ERMAT', 'REYNA', 'ERPAT', 'HARI'),
#    ('KUYA', 'HIPAG', 'ATE', 'BAYAW'),
#    ('INA', 'HIPAG', 'AMA', 'BAYAW'),
#    ('TITA', 'REYNA', 'TITO', 'HARI'),
#    ('INA', 'TITA', 'AMA', 'TITO'),
#    ('INA', 'PRINSESA', 'AMA', 'PRINSIPE'),
#    ('TITA', 'REYNA', 'TITO', 'HARI'),
#    ('TITA', 'ERMAT', 'TITO', 'ERPAT'),
#    ('LOLA', 'TITA', 'LOLO', 'TITO'),
#    ('LOLA', 'TITA', 'LOLO', 'TITO'),
#    ('HIPAG', 'REYNA', 'BAYAW', 'HARI'),
#    ('HIPAG', 'TITA', 'BAYAW', 'TITO'),
#    ('TITA', 'ERMAT', 'TITO', 'ERPAT'),
#    ('NANAY', 'HIPAG', 'TATAY', 'BAYAW'),
#    ('NANAY', 'HIPAG', 'TATAY', 'BAYAW'),
#    ('KUYA', 'PRINSESA', 'ATE', 'PRINSIPE'),
#    ('ERMAT', 'MAMA', 'ERPAT', 'PAPA'),
#    ('TIYA', 'MAMA', 'TIYO', 'PAPA'),
#    ('TITA', 'MAMA', 'TITO', 'PAPA'),
#    ('LOLA', 'PRINSESA', 'LOLO', 'PRINSIPE'),
#    ('TIYA', 'MAMA', 'TIYO', 'PAPA'),
#    ('NINANG', 'HIPAG', 'NINONG', 'BAYAW'),
#    ('NANAY', 'TIYA', 'TATAY', 'TIYO'),
#    ('TIYA', 'REYNA', 'TIYO', 'HARI'),
#    ('ERMAT', 'REYNA', 'ERPAT', 'HARI'),
#    ('BABAE', 'MAMA', 'LALAKI', 'PAPA'),
#    ('ERMAT', 'MAMA', 'ERPAT', 'PAPA'),
#    ('HIPAG', 'ERMAT', 'BAYAW', 'ERPAT'),
#    ('TIYA', 'PRINSESA', 'TIYO', 'PRINSIPE'),
#    ('PRINSESA', 'MAMA', 'PRINSIPE', 'PAPA'),
#    ('HIPAG', 'ERMAT', 'BAYAW', 'ERPAT'),
#    ('KUYA', 'PRINSESA', 'ATE', 'PRINSIPE'),
#    ('HIPAG', 'PRINSESA', 'BAYAW', 'PRINSIPE'),
#    ('BABAE', 'MAMA', 'LALAKI', 'PAPA'),
#    ('NINANG', 'HIPAG', 'NINONG', 'BAYAW'),
#    ('HIPAG', 'PRINSESA', 'BAYAW', 'PRINSIPE'),
#    ('TITA', 'MAMA', 'TITO', 'PAPA'),
#    ('NANAY', 'TITA', 'TATAY', 'TITO'),
#    ('INA', 'TITA', 'AMA', 'TITO'),
#    ('ERMAT', 'PRINSESA', 'ERPAT', 'PRINSIPE'),
#    ('TITA', 'PRINSESA', 'TITO', 'PRINSIPE'),
#    ('LOLA', 'PRINSESA', 'LOLO', 'PRINSIPE'),
#    ('NINANG', 'HIPAG', 'NINONG', 'BAYAW'),
#    ('INA', 'ERMAT', 'AMA', 'ERPAT'),
#    ('INA', 'PRINSESA', 'AMA', 'PRINSIPE'),
#    ('NINANG', 'ERMAT', 'NINONG', 'ERPAT'),
#    ('LOLA', 'HIPAG', 'LOLO', 'BAYAW'),
#    ('KUYA', 'REYNA', 'ATE', 'HARI'),
#    ('KUYA', 'HIPAG', 'ATE', 'BAYAW'),
#    ('INA', 'ERMAT', 'AMA', 'ERPAT'),
#    ('NINANG', 'TITA', 'NINONG', 'TITO'),
#    ('TIYA', 'TITA', 'TIYO', 'TITO'),
#    ('ERMAT', 'PRINSESA', 'ERPAT', 'PRINSIPE'),
#    ('NANAY', 'TIYA', 'TATAY', 'TIYO'),
#    ('TIYA', 'PRINSESA', 'TIYO', 'PRINSIPE'),
#    ('LOLA', 'PRINSESA', 'LOLO', 'PRINSIPE'),
#    ('TIYA', 'ERMAT', 'TIYO', 'ERPAT'),
#    ('KUYA', 'ERMAT', 'ATE', 'ERPAT'),
#    ('INA', 'HIPAG', 'AMA', 'BAYAW'),
#    ('NANAY', 'PRINSESA', 'TATAY', 'PRINSIPE'),
#    ('HIPAG', 'ERMAT', 'BAYAW', 'ERPAT'),
#    ('LOLA', 'TITA', 'LOLO', 'TITO'),
#    ('KUYA', 'HIPAG', 'ATE', 'BAYAW'),
#    ('HIPAG', 'REYNA', 'BAYAW', 'HARI'),
#    ('INA', 'HIPAG', 'AMA', 'BAYAW'),
#    ('TIYA', 'MAMA', 'TIYO', 'PAPA'),
#    ('KUYA', 'ERMAT', 'ATE', 'ERPAT'),
#    ('TIYA', 'PRINSESA', 'TIYO', 'PRINSIPE'),
#    ('KUYA', 'REYNA', 'ATE', 'HARI'),
#    ('TIYA', 'TITA', 'TIYO', 'TITO'),
#    ('INA', 'TITA', 'AMA', 'TITO'),
#    ('LOLA', 'HIPAG', 'LOLO', 'BAYAW'),
#    ('KUYA', 'NINANG', 'ATE', 'NINONG'),
#    ('NANAY', 'HIPAG', 'TATAY', 'BAYAW'),
#    ('NINANG', 'TITA', 'NINONG', 'TITO'),
#    ('NINANG', 'TITA', 'NINONG', 'TITO'),
#    ('NANAY', 'TITA', 'TATAY', 'TITO')],
#   'section': 'total'}]

# %%
# Returns {analogy_header:(a, b, c, d)[]}, i.e a map of lists of tuples containing 4 words
def read_analogy_file(analogy_file):
    analogies = {}
    current_topic = "default"
    analogies[current_topic] = []
    for line in analogy_file.readlines():
        if line.startswith(": "):
            current_topic = line[2:]
            analogies[current_topic] = []
        else:
            a, b, c, d = line.split()
            analogies[current_topic].append((a, b, c, d))
    return analogies


# Returns {analogy_header:float[]}, i.e. a map of accuracy scores
def accuracy(model, analogy_file, topn=5):
    analogies = read_analogy_file(analogy_file)
    scores = {}
    for header in analogies:

        tasks = analogies[header]

        # Initialize list containing scores for topn
        topn_scores = [0] * topn

        for task in tasks:

            # Retrieve the words
            a = task[0]
            b = task[1]
            c = task[2]
            d = task[3]
            # --------------------------------
            # WARNING WARNING WARNING WARNING
            # WARNING WARNING WARNING WARNING
            # Pa-ayos kung tama ung arrangement
            # --------------------------------
            print(a," is to ", b, "as ", c, "is to ",d,"\n")
            tuples = model.wv.most_similar(
                positive=[c, b], negative=[d], topn=topn)

            for i in range(0, topn):
                # Get subset of top i tuple
                sub_tuple = tuples[0:i]

                # Filter out the scores, only the word shall remain
                word_list = [tup[0] for tup in sub_tuple]

                # Count if it is in the word list
                if a in word_list:
                    topn_scores[i] = topn_scores[i] + 1

        # Normalize and assign
        count = len(tasks)
        
        if count == 0:
            scores[header] = [0] * topn
        else:
            scores[header] = [n / count for n in topn_scores]

    return scores

# Sample usage
print(accuracy(model, open("output.magkasalungat.csv", "r", encoding="utf-8"), 10))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-12b66109e98c> in <module>()
#      63
#      64 # Sample usage
# ---> 65 print(accuracy(model, open("output.magkasalungat.csv", "r", encoding="utf-8"), 10))
#
# <ipython-input-19-12b66109e98c> in accuracy(model, analogy_file, topn)
#      16 # Returns {analogy_header:float[]}, i.e. a map of accuracy scores
#      17 def accuracy(model, analogy_file, topn=5):
# ---> 18     analogies = read_analogy_file(analogy_file)
#      19     scores = {}
#      20     for header in analogies:
#
# <ipython-input-19-12b66109e98c> in read_analogy_file(analogy_file)
#       9             analogies[current_topic] = []
#      10         else:
# ---> 11             a, b, c, d = line.split()
#      12             analogies[current_topic].append((a, b, c, d))
#      13     return analogies
#
# ValueError: too many values to unpack (expected 4)

# %%
mo
